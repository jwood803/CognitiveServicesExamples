# %%
# !pip install requests

# %%
import requests

# %%
key = "7247b86f1853463b818d8c9b8dd828ef"
base_url = "https://api.labs.cognitive.microsoft.com/urlpreview/v7.0/search"

# %%
url = "https://jonwood.co/"

# %%
preview_url = requests.utils.quote(url)

# %%
headers = {
    "Ocp-Apim-Subscription-Key": key
}

# %%
response = requests.get(f"{base_url}?q={preview_url}", headers=headers)

# %%
response.json()
# Out:
# {'_type': 'WebPage',
#  'isFamilyFriendly': True,
#  'name': 'Jon Wood',
#  'url': 'https://jonwood.co/',
#  'description': 'Blog about software development (.NET, C#, F#, data science, machine learning), book reviews, and issues related to software.'}

# %%
specific_url = requests.utils.quote("https://jonwood.co/blog/2018/12/31/5-books-to-become-a-better-software-developer")

# %%
response = requests.get(f"{base_url}?q={specific_url}", headers=headers)

# %%
resp = response.json()

# %%
resp
# Out:
# {'_type': 'WebPage',
#  'primaryImageOfPage': {'contentUrl': 'http://static1.squarespace.com/static/521545a6e4b0734032a27076/52154697e4b0fe422ebb9ca8/5c2772a1c2241bc8b4db7c1d/1546269067654/edited.jpg?format=1500w'},
#  'isFamilyFriendly': True,
#  'name': '5 Books To Become a Better Software Developer — Jon Wood',
#  'url': 'https://jonwood.co/blog/2018/12/31/5-books-to-become-a-better-software-developer',
#  'description': 'Dec 31 5 Books To Become a Better Software Developer. Jon Wood. Screencast, Top Five. This video goes over the top five books I found to help me become a better software developer. Hope you will find it useful. If you have a book that has helped you, feel free to put it in the comments.'}

# %%
![]()

# %%
from IPython.display import Image, display

# %%
display(Image(resp["primaryImageOfPage"]["contentUrl"]))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-39-c09f0af030b4> in <module>
# ----> 1 display(Image(resp["primaryImageOfPage"]["contentUrl"]))
#
# ~\Anaconda3\lib\site-packages\IPython\core\display.py in __init__(self, data, url, filename, format, embed, width, height, retina, unconfined, metadata)
#    1175
#    1176         if self.embed and self.format not in self._ACCEPTABLE_EMBEDDINGS:
# -> 1177             raise ValueError("Cannot embed the '%s' image format" % (self.format))
#    1178         if self.embed:
#    1179             self._mimetype = self._MIMETYPES.get(self.format)
#
# ValueError: Cannot embed the 'jpg?format=1500w' image format

# %%
image = resp["primaryImageOfPage"]["contentUrl"]
image
# Out:
# 'http://static1.squarespace.com/static/521545a6e4b0734032a27076/52154697e4b0fe422ebb9ca8/5c2772a1c2241bc8b4db7c1d/1546269067654/edited.jpg?format=1500w'

# %%
image = image.split("?")[0]
image
# Out:
# 'http://static1.squarespace.com/static/521545a6e4b0734032a27076/52154697e4b0fe422ebb9ca8/5c2772a1c2241bc8b4db7c1d/1546269067654/edited.jpg'

# %%
display(Image(image))

# %%
video_url = requests.utils.quote("https://www.youtube.com/watch?v=9kRsUopIhN0")

# %%
response = requests.get(f"{base_url}?q={video_url}", headers=headers)

# %%
response.json()
# Out:
# {'_type': 'WebPage',
#  'primaryImageOfPage': {'contentUrl': 'https://i.ytimg.com/vi/9kRsUopIhN0/maxresdefault.jpg'},
#  'isFamilyFriendly': True,
#  'name': '5 Books To Become a Better Software Developer',
#  'url': 'https://www.youtube.com/watch?v=9kRsUopIhN0',
#  'description': "My choice for the five best books in order to become a better software developer. Books: The Effective Engineer - https://amzn.to/2s05CyB So Good They Can't ..."}

# %%
resp = response.json()

# %%
display(Image(resp["primaryImageOfPage"]["contentUrl"]))
